# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the dataset to the python environment

# %%
data=pd.read_csv('/home/anaswara/Desktop/DSA ACTIVITIES/Assignment/cars_data.csv')
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %%
cars_data=pd.DataFrame(data)
cars_data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # Check for the null values present in the dataset

# %%
pd.isnull(data).sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # Plot a bar graph of male vs female buyers participated in the sales

# %%
sns.countplot('Buyer Gender',data=cars_data)
plt.grid()
# Out:
# /home/anaswara/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data[['Buyer Gender']].value_counts()
# Out:
# Buyer Gender
# Female          5052
# Male            4948
# dtype: int64

# %% [markdown]
# # Find the top 5 cars based on their sales price

# %%
cars_data.sort_values('Sale Price')
# Out:
#             Make                 Model   Nickname Car Gender Buyer Gender  \
# 3513         Geo               Tracker     Nowell       Male         Male
# 7234        Ford             Excursion     Patric       Male         Male
# 5956       Mazda                Mazda6     Milzie       Male       Female
# 6270      Nissan                 240SX     Paloma       Male       Female
# 6241     Lincoln  Continental Mark VII    Malissa     Female       Female
# ...          ...                   ...        ...        ...          ...
# 302        Lexus                    ES       Brig     Female         Male
# 9032       Mazda                  MX-6  Sylvester     Female         Male
# 3460       Lexus                    LX      Aldin     Female         Male
# 1270        Audi                    A6      Thorn       Male         Male
# 5984  Volkswagen             Jetta III    Rachael     Female       Female
#
#       Buyer Age              Buzzword      Country           City  \
# ...

# %%
top_5=cars_data.sort_values('Sale Price').head(5)
top_5
# Out:
#          Make                 Model Nickname Car Gender Buyer Gender  \
# 3513      Geo               Tracker   Nowell       Male         Male
# 7234     Ford             Excursion   Patric       Male         Male
# 5956    Mazda                Mazda6   Milzie       Male       Female
# 6270   Nissan                 240SX   Paloma       Male       Female
# 6241  Lincoln  Continental Mark VII  Malissa     Female       Female
#
#       Buyer Age              Buzzword      Country        City  \
# 3513         64             impactful        Japan        Hagi
# 7234         30         Decentralized   Azerbaijan    Zaqatala
# 5956         39            motivating      Albania       Shezë
# 6270         48         Self-enabling  Philippines       Lanas
# 6241         57  budgetary management       Russia  Safakulevo
#
#       Dealer Latitude  Dealer Longitude      Color  New Car Purchase Date  \
# 3513        32.428624        130.649340     Orange     True    28/01/2016
# ...

# %% [markdown]
# # Find the least 5 cars based on their Resell price

# %%
cars_data.sort_values('Resell Price',ascending=False).head(5)
# Out:
#            Make           Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 3224  Chevrolet          Camaro   Durand     Female         Male         50
# 8406       Ford  Econoline E350      Ree     Female       Female         49
# 222       Acura              TL    Zelma       Male       Female         42
# 2512        GMC     Sierra 2500     Neal     Female         Male         64
# 5173  Chevrolet          Blazer     Cari     Female       Female         64
#
#                       Buzzword      Country      City  Dealer Latitude  \
# 3224  Graphical User Interface  Philippines    Teresa        14.570454
# 8406                    Robust  Philippines      Suyo        16.875970
# 222                    Virtual      Ukraine  Radekhiv        50.283692
# 2512               parallelism        China  Pengdian        31.528572
# 5173                motivating        China   Fuchang        37.868872
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %%
least_5=cars_data.sort_values('Resell Price').tail(5)
least_5
# Out:
#            Make           Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 5173  Chevrolet          Blazer     Cari     Female       Female         64
# 2512        GMC     Sierra 2500     Neal     Female         Male         64
# 222       Acura              TL    Zelma       Male       Female         42
# 8406       Ford  Econoline E350      Ree     Female       Female         49
# 3224  Chevrolet          Camaro   Durand     Female         Male         50
#
#                       Buzzword      Country      City  Dealer Latitude  \
# 5173                motivating        China   Fuchang        37.868872
# 2512               parallelism        China  Pengdian        31.528572
# 222                    Virtual      Ukraine  Radekhiv        50.283692
# 8406                    Robust  Philippines      Suyo        16.875970
# 3224  Graphical User Interface  Philippines    Teresa        14.570454
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...
